# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
merge_df = pd.merge(study_results, mouse_metadata, on="Mouse ID", how="outer")

# Display the data table for preview
#display(mouse_metadata)
#display(study_results)
display(merge_df)
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice
mice_count = len(pd.unique(merge_df['Mouse ID']))
mice_count
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice = merge_df[merge_df.duplicated(subset=['Mouse ID', 'Timepoint'], keep=False)]['Mouse ID'].unique()
duplicate_mice
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mice_duplicate = merge_df.loc[merge_df["Mouse ID"] == "g989"]
mice_duplicate
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# ...

# %%
to_remove = mice_duplicate.index
cleaned_data = merge_df.drop(to_remove)
cleaned_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_mice_count = len(pd.unique(cleaned_data['Mouse ID']))
clean_mice_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
tumor_regimen_mean = cleaned_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
tumor_regimen_mean
# Out:
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.320930
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
tumor_regimen_median = cleaned_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
tumor_regimen_median
# Out:
# Drug Regimen
# Capomulin    41.557809
# Ceftamin     51.776157
# Infubinol    51.820584
# Ketapril     53.698743
# Naftisol     52.509285
# Placebo      52.288934
# Propriva     50.446266
# Ramicane     40.673236
# Stelasyn     52.431737
# Zoniferol    51.818479
# Name: Tumor Volume (mm3), dtype: float64

# %%
tumor_regimen_variance = cleaned_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
tumor_regimen_variance
# Out:
# Drug Regimen
# Capomulin    24.947764
# Ceftamin     39.290177
# Infubinol    43.128684
# Ketapril     68.553577
# Naftisol     66.173479
# Placebo      61.168083
# Propriva     43.852013
# Ramicane     23.486704
# Stelasyn     59.450562
# Zoniferol    48.533355
# Name: Tumor Volume (mm3), dtype: float64

# %%
tumor_regimen_std = cleaned_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
tumor_regimen_std
# Out:
# Drug Regimen
# Capomulin    4.994774
# Ceftamin     6.268188
# Infubinol    6.567243
# Ketapril     8.279709
# Naftisol     8.134708
# Placebo      7.821003
# Propriva     6.622085
# Ramicane     4.846308
# Stelasyn     7.710419
# Zoniferol    6.966589
# Name: Tumor Volume (mm3), dtype: float64

# %%
tumor_regimen_sem = cleaned_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()
tumor_regimen_sem
# Out:
# Drug Regimen
# Capomulin    0.329346
# Ceftamin     0.469821
# Infubinol    0.492236
# Ketapril     0.603860
# Naftisol     0.596466
# Placebo      0.581331
# Propriva     0.544332
# Ramicane     0.320955
# Stelasyn     0.573111
# Zoniferol    0.516398
# Name: Tumor Volume (mm3), dtype: float64

# %%
type(tumor_regimen_sem)
# Out:
# pandas.core.series.Series

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
summary_stats_df = pd.DataFrame({"Mean Tumor Volume" : tumor_regimen_mean,
                                "Median Tumor Volume" : tumor_regimen_median,
                                "Tumor Volume Variance" : tumor_regimen_variance,
                                "Tumor Volume Std. Dev." : tumor_regimen_std,
                                "Tumor Volume Std. Err." : tumor_regimen_sem})
display(summary_stats_df)
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
agg_summary = cleaned_data.groupby('Drug Regimen').agg({'Tumor Volume (mm3)': 
                                                         ['mean', 'median', 'var', 'std', 'sem']})
agg_summary
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
data_to_plot = cleaned_data["Drug Regimen"].value_counts()
bar_chart = data_to_plot.plot(kind='bar')
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
display(bar_chart)
# Out:
# <Axes: xlabel='Drug Regimen', ylabel='# of Observed Mouse Timepoints'>

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
x_axis = data_to_plot.index
y_axis = data_to_plot.values
plt.bar(x_axis, y_axis)
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
# Out:
# Text(0, 0.5, '# of Observed Mouse Timepoints')

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
pie_to_plot = cleaned_data["Sex"].value_counts()
pie_to_plot.plot(kind="pie", autopct='%1.1f%%')
plt.ylabel("Sex")
# Out:
# Text(0, 0.5, 'Sex')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
pie_to_plot = cleaned_data["Sex"].value_counts()
labels = pie_to_plot.index
plt.pie(pie_to_plot, labels = labels, autopct='%1.1f%%')
plt.ylabel("Sex")
# Out:
# Text(0, 0.5, 'Sex')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
treatment_regimens = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
#filter_data = cleaned_data[cleaned_data["Drug Regimen"].isin(treatment_regimens)]
mouse_groupby_max = cleaned_data.groupby("Mouse ID")["Timepoint"].max()
mouse_groupby_df = mouse_groupby_max.reset_index()
display(mouse_groupby_df)

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
last_tumor_df = mouse_groupby_df.merge(cleaned_data, how='left', on = ["Mouse ID", "Timepoint"])
display(last_tumor_df)
# Out:
#     Mouse ID  Timepoint
# 0       a203         45
# 1       a251         45
# 2       a262         45
# 3       a275         45
# 4       a366         30
# ..       ...        ...
# 243     z435         10
# 244     z578         45
# 245     z581         45
# 246     z795         45
# 247     z969         45
#
# [248 rows x 2 columns]
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 243     z435         10           48.710661                 0     Propriva
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
for regimen in treatments:
    regimen_data = last_tumor_df[last_tumor_df['Drug Regimen'] == regimen]['Tumor Volume (mm3)']
    tumor_vol.append(regimen_data)
    
    # add subset 
    quartiles = regimen_data.quantile([0.25, 0.5, 0.75])
    lower_q = quartiles[0.25]
    upper_q = quartiles[0.75]
    iqr = upper_q - lower_q
        
        # Determine outliers using upper and lower bounds
       
    lower_bound = lower_q - 1.5 * iqr
    upper_bound = upper_q + 1.5 * iqr
       
    outliers = regimen_data[(regimen_data < lower_bound) | (regimen_data > upper_bound)]
        
       
    print(f"{regimen}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
plt.boxplot(tumor_vol, labels=treatments, flierprops = {'marker' :"o", 'markersize' : 12, 'markeredgecolor' : 'black', 'markerfacecolor' : 'r'})
      
plt.ylabel("Final Tumor Volume (mm3)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
mouse_id = 'l509'
capomulin_data = cleaned_data[cleaned_data["Drug Regimen"] == "Capomulin"]	
x_axis_timepoint = capomulin_data[capomulin_data['Mouse ID'] == mouse_id]['Timepoint']
y_axis_tumor = capomulin_data[capomulin_data["Mouse ID"] == mouse_id]["Tumor Volume (mm3)"]

plt.plot(x_axis_timepoint, y_axis_tumor)
plt.title(f"Capomulin treatment of mouse {mouse_id}")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
capomulin_data = cleaned_data[cleaned_data["Drug Regimen"] == "Capomulin"]
average_tumor_volume = capomulin_data.groupby("Mouse ID")["Tumor Volume (mm3)"].mean()
capomulin_merged = pd.merge(capomulin_data, average_tumor_volume, on=["Mouse ID"])
capomulin_merged.rename(columns={"Tumor Volume (mm3)_y" : "Tumor Volume (mm3) Mean"})
x_weight = capomulin_data["Weight (g)"]
y_avg_tumor = capomulin_merged["Tumor Volume (mm3)_y"]

plt.scatter(x_weight, y_avg_tumor, marker = 'o', facecolors = 'blue')
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()

# %%
capomulin_merged
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)_x  Metastatic Sites Drug Regimen  \
# 0       b128          0             45.000000                 0    Capomulin
# 1       b128          5             45.651331                 0    Capomulin
# 2       b128         10             43.270852                 0    Capomulin
# 3       b128         15             43.784893                 0    Capomulin
# 4       b128         20             42.731552                 0    Capomulin
# ..       ...        ...                   ...               ...          ...
# 225     m601         25             33.118756                 1    Capomulin
# 226     m601         30             31.758275                 1    Capomulin
# 227     m601         35             30.834357                 1    Capomulin
# 228     m601         40             31.378045                 1    Capomulin
# 229     m601         45             28.430964                 1    Capomulin
#
# ...

# %%
capomulin_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

capomulin_data = cleaned_data[cleaned_data["Drug Regimen"] == "Capomulin"]
average_tumor_volume = capomulin_data.groupby("Mouse ID")["Tumor Volume (mm3)"].mean()
capomulin_merged = pd.merge(capomulin_data, average_tumor_volume, on=["Mouse ID"])
capomulin_merged.rename(columns={"Tumor Volume (mm3)_y" : "Tumor Volume (mm3) Mean"})
x_weight = capomulin_data["Weight (g)"]
y_avg_tumor = capomulin_merged["Tumor Volume (mm3)_y"]

slope, int, rvalue, pvalue, std_error = st.linregress(x_weight, y_avg_tumor)
reg_data = slope * x_weight + int
plt.plot(x_weight, reg_data, color = 'r')

plt.scatter(x_weight, y_avg_tumor, marker = 'o', facecolors = 'royalblue', alpha = .8)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()
